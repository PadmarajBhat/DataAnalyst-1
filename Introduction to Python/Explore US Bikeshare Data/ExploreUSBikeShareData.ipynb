# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 0A3A-E61C
#
#  Directory of C:\Users\padmaraj.bhat\OneDrive - Accenture\Git\GitHub\Data-Analyst Term 1
#
# 03/03/2019  09:57 PM    <DIR>          .
# 03/03/2019  09:57 PM    <DIR>          ..
# 03/03/2019  09:55 PM    <DIR>          .ipynb_checkpoints
# 03/03/2019  09:56 PM            45,967 chicago.csv
# 03/03/2019  09:57 PM               696 ExploreUSBikeShareData.ipynb
# 03/02/2019  06:46 PM           237,786 IntroToPythonProgramming.ipynb
# 02/25/2019  07:32 PM                93 my_file.txt
#                4 File(s)        284,542 bytes
#                3 Dir(s)  16,635,400,192 bytes free

# %%
chicago_df = pd.read_csv('chicago.csv')

# %%
chicago_df
# Out:
#               Start Time             End Time  Trip Duration  \
# 0    2017-05-29 18:36:27  2017-05-29 18:49:27            780
# 1    2017-06-12 19:00:33  2017-06-12 19:24:22           1429
# 2    2017-02-13 17:02:02  2017-02-13 17:20:10           1088
# 3    2017-04-24 18:39:45  2017-04-24 18:54:59            914
# 4    2017-01-26 15:36:07  2017-01-26 15:43:21            434
# 5    2017-06-21 09:43:54  2017-06-21 10:01:31           1057
# 6    2017-04-24 08:33:31  2017-04-24 08:38:47            316
# 7    2017-03-21 07:23:58  2017-03-21 07:33:17            559
# 8    2017-01-14 12:16:20  2017-01-14 12:58:17           2517
# 9    2017-04-06 09:15:52  2017-04-06 09:22:11            379
# 10   2017-06-13 17:02:44  2017-06-13 17:08:17            333
# 11   2017-03-09 09:15:39  2017-03-09 09:18:56            197
# 12   2017-03-22 06:54:00  2017-03-22 06:59:02            302
# 13   2017-02-21 17:51:52  2017-02-21 17:55:03            191
# ...

# %%
chicago_df['Start Time'] = pd.to_datetime(chicago_df['Start Time'])
chicago_df['Hours'] = chicago_df['Start Time'].dt.hour
print("Most popular Hour :",chicago_df.Hours.mode()[0])
# Out:
# Most popular Hour : 17

# %%
chicago_df['User Type'].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
chicago_df['User Type'].value_counts()
# Out:
# Subscriber    330
# Customer       70
# Name: User Type, dtype: int64

# %%
chicago_df['Start Time'].dt.weekday
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      3
# 5      2
# 6      0
# 7      1
# 8      5
# 9      3
# 10     1
# 11     3
# 12     2
# 13     1
# 14     0
# 15     1
# 16     2
# 17     0
# 18     5
# 19     6
# 20     1
# 21     2
# 22     1
# 23     6
# 24     2
# 25     2
# 26     5
# 27     1
# 28     2
# 29     1
#       ..
# 370    2
# 371    2
# 372    3
# 373    0
# 374    5
# 375    5
# 376    4
# 377    1
# 378    4
# 379    0
# 380    6
# 381    0
# 382    3
# 383    2
# 384    0
# 385    6
# 386    3
# 387    1
# 388    5
# 389    5
# 390    3
# 391    6
# 392    5
# 393    1
# 394    2
# 395    0
# 396    0
# 397    4
# 398    1
# 399    1
# Name: Start Time, Length: 400, dtype: int64

# %%
chicago_df['Day'] = chicago_df['Start Time'].dt.weekday_name

# %%
def groupByDay(day):
    return chicago_df.Day.value_counts()[day]
groupByDay('Tuesday')
# Out:
# 64
